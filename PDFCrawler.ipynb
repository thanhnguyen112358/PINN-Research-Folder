# %%
import time
import os
import logging
import csv
from typing import List, Dict, Optional

# Official Clarivate Starter‑API client
import clarivate.wos_starter.client as wos
from clarivate.wos_starter.client import Configuration, ApiClient, DocumentsApi
from clarivate.wos_starter.client.rest import ApiException

import requests  # for Unpaywall + direct PDF fetch

"""
WoS Starter‑API PDF harvester (client edition)
=============================================
* Works with the 2025‑Q2 response envelope (`metadata` + `hits`).
* Paginates until it collects `MAX_RESULTS` (default = 100).
* Extracts `title` + `doi` (prefers `identifiers.doi`).
* Saves a CSV, then tries Unpaywall for OA PDFs.
* API key remains hard‑coded per user request.
"""

# -----------------------------------------------------------------------------
# 0. User‑configurable constants
# -----------------------------------------------------------------------------
API_KEY = "1f8efd1acb29e46412a32eba3f85b7b1690a1024"
API_HOST = "https://api.clarivate.com/apis/wos-starter/v1"
UNPAYWALL_EMAIL = "dn018@bucknell.edu"  # replace with your own
MAX_RESULTS = 100                        # stop after N papers
PAGE_SIZE = 50                           # WoS Starter max per page

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")

# -----------------------------------------------------------------------------
# 1. Low‑level: call Clarivate SDK and return plain dict
# -----------------------------------------------------------------------------

def wos_search(query: str, *, limit: int, page: int) -> dict:
    cfg = Configuration(host=API_HOST)
    cfg.api_key["ClarivateApiKeyAuth"] = API_KEY
    try:
        with ApiClient(cfg) as client:
            docs_api = DocumentsApi(client)
            resp = docs_api.documents_get(q=query, db="WOS", limit=limit, page=page, detail="full")
            return resp.to_dict()
    except ApiException as exc:
        logging.error("WoS API %s – %s", exc.status, exc.body)
        raise

# -----------------------------------------------------------------------------
# 2. Collect title+DOI up to MAX_RESULTS
# -----------------------------------------------------------------------------

def get_paper_list(query: str, *, max_results: int = MAX_RESULTS) -> List[Dict[str, Optional[str]]]:
    papers: List[Dict[str, Optional[str]]] = []
    page = 1
    while len(papers) < max_results:
        remaining = max_results - len(papers)
        limit = min(PAGE_SIZE, remaining)
        data = wos_search(query, limit=limit, page=page)

        # Starter‑API 1.0.0 puts records in "hits"
        recs = (
            data.get("hits")
            or data.get("records")
            or data.get("documents")
            or data.get("data")
            or []
        )
        if not recs:
            logging.warning("No records on page %d – stopping.", page)
            break

        logging.info("Page %d – %d records", page, len(recs))
        for rec in recs:
            title = rec.get("title") or "<no title>"
            doi = (
                rec.get("doi")
                or rec.get("identifiers", {}).get("doi")
                or rec.get("document_identifiers", {}).get("doi")
            )
            papers.append({"title": title, "doi": doi})
            if len(papers) >= max_results:
                break

        # pagination bookkeeping
        if len(recs) < limit:
            break  # last page
        page += 1
    return papers

# -----------------------------------------------------------------------------
# 3. Unpaywall PDF downloader
# -----------------------------------------------------------------------------

def download_pdf(doi: Optional[str], *, save_dir: str = "pdfs") -> bool:
    if not doi:
        logging.info("No DOI – skipping download.")
        return False
    try:
        upw_resp = requests.get(
            f"https://api.unpaywall.org/v2/{doi}",
            params={"email": UNPAYWALL_EMAIL},
            timeout=20,
        )
        upw_resp.raise_for_status()
        upw_data = upw_resp.json()
        loc = upw_data.get("best_oa_location") or next(iter(upw_data.get("oa_locations") or []), {})
        pdf_url = loc.get("url_for_pdf")
        if not pdf_url:
            logging.info("No OA PDF for %s", doi)
            return False
        pdf_resp = requests.get(pdf_url, timeout=30)
        pdf_resp.raise_for_status()
        os.makedirs(save_dir, exist_ok=True)
        filename = doi.replace("/", "_") + ".pdf"
        path = os.path.join(save_dir, filename)
        with open(path, "wb") as fh:
            fh.write(pdf_resp.content)
        logging.info("Saved PDF → %s", path)
        return True
    except requests.exceptions.RequestException as exc:
        logging.warning("PDF download failed for %s – %s", doi, exc)
        return False

# -----------------------------------------------------------------------------
# 4. CSV helper
# -----------------------------------------------------------------------------

def save_csv(rows: List[Dict[str, str]], *, path: str = "wos_results.csv") -> None:
    if not rows:
        logging.info("No records – skip CSV.")
        return
    with open(path, "w", newline="", encoding="utf-8") as fh:
        writer = csv.DictWriter(fh, fieldnames=["title", "doi"], extrasaction="ignore")
        writer.writeheader()
        writer.writerows(rows)
    logging.info("Wrote CSV → %s", path)

# -----------------------------------------------------------------------------
# 5. Main
# -----------------------------------------------------------------------------

def main():
    query = "TS=(biomass gasification)"
    papers = get_paper_list(query, max_results=MAX_RESULTS)
    save_csv(papers)
    for p in papers:
        logging.info("TITLE: %s", p["title"])
        download_pdf(p["doi"], save_dir="downloaded_pdfs")
        time.sleep(1.1)  # polite Unpaywall delay

if __name__ == "__main__":
    main()
# Out:
# 2025-06-05 00:21:08,787 [INFO] Page 1 – 50 records
# 2025-06-05 00:21:10,268 [INFO] Page 2 – 50 records
# 2025-06-05 00:21:10,272 [INFO] Wrote CSV → wos_results.csv
# 2025-06-05 00:21:10,273 [INFO] TITLE: CATALYZED STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:21:11,383 [INFO] No OA PDF for 10.1016/0165-2370(79)80013-3
# 2025-06-05 00:21:12,485 [INFO] TITLE: FLUIDIZED-BED GASIFICATION OF SOLID-WASTES AND BIOMASS - CIL PROGRAM
# 2025-06-05 00:21:12,486 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:13,588 [INFO] TITLE: DEVELOPMENT OF PROTOTYPE PACKAGED GASIFICATION AND COMBUSTION SYSTEMS FOR REFINED BIOMASS AIR BLOWN PRODUCER GAS
# 2025-06-05 00:21:13,589 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:14,690 [INFO] TITLE: BIOMASS GASIFICATION AT THE FOCUS OF THE ODEILLO (FRANCE) 1 MWTH SOLAR FURNACE
# 2025-06-05 00:21:14,691 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:15,792 [INFO] TITLE: FUNDAMENTAL INVESTIGATION OF THE STEAM GASIFICATION OF BIOMASS IN THE PRESENCE OF CATALYSTS
# 2025-06-05 00:21:15,793 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:16,894 [INFO] TITLE: EFFECTS OF RESIDENCE TIME, TEMPERATURE, AND PRESSURE ON THE STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:21:16,895 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:17,996 [INFO] TITLE: ASSESSMENT OF THE GASIFICATION CHARACTERISTICS OF SOME AGRICULTURAL AND FOREST INDUSTRY RESIDUES USING A LABORATORY GASIFIER
# 2025-06-05 00:21:19,089 [INFO] No OA PDF for 10.1016/0304-3967(79)90019-2
# 2025-06-05 00:21:20,192 [INFO] TITLE: SOLAR GASIFICATION OF COAL, ACTIVATED CARBON, COKE AND COAL AND BIOMASS MIXTURES
# 2025-06-05 00:21:21,026 [INFO] No OA PDF for 10.1016/0038-092X(80)90347-3
# 2025-06-05 00:21:22,126 [INFO] TITLE: GASOHOL-BIOMASS DEVELOPMENTS - METHANE-METHANOL BY CATALYTIC GASIFICATION OF BIOMASS
# 2025-06-05 00:21:22,126 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:23,228 [INFO] TITLE: MATHEMATICAL-MODEL FOR THE FLUID-BED GASIFICATION OF BIOMASS MATERIALS - APPLICATION TO FEEDLOT MANURE
# 2025-06-05 00:21:24,451 [INFO] No OA PDF for 10.1021/i200015a019
# 2025-06-05 00:21:25,553 [INFO] TITLE: ORGANIC-ACID PRODUCTION FROM CO2-H2 AND CO-H2 BY MIXED-CULTURE ANAEROBES
# 2025-06-05 00:21:26,415 [INFO] No OA PDF for 10.1002/bit.260231012
# 2025-06-05 00:21:27,516 [INFO] TITLE: BIOTHERMAL GASIFICATION OF BIOMASS AND ORGANIC RESIDUES
# 2025-06-05 00:21:27,516 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:28,619 [INFO] TITLE: GASIFICATION OF BIOMASS IN A FLUIDIZED-BED
# 2025-06-05 00:21:29,480 [INFO] No OA PDF for 10.1016/0300-9467(81)80017-2
# 2025-06-05 00:21:30,582 [INFO] TITLE: BIOMASS GASIFICATION FOR PRODUCTION OF GASEOUS AND LIQUID FUELS
# 2025-06-05 00:21:30,583 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:31,684 [INFO] TITLE: ENTRAINED PYROLYSIS-GASIFICATION OF BIOMASS TO SYNGAS
# 2025-06-05 00:21:31,684 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:32,786 [INFO] TITLE: THERMAL BIOMASS GASIFICATION
# 2025-06-05 00:21:32,786 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:33,888 [INFO] TITLE: HIGH-TEMPERATURE GASIFICATION KINETICS OF BIOMASS PYROLYSIS
# 2025-06-05 00:21:34,721 [INFO] No OA PDF for 10.1016/0165-2370(81)80017-4
# 2025-06-05 00:21:35,822 [INFO] TITLE: ECONOMIC-POTENTIAL OF ON-FARM BIOMASS GASIFICATION FOR CORN DRYING
# 2025-06-05 00:21:35,822 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:36,924 [INFO] TITLE: FEASIBILITY OF GASIFICATION FOR DRYING AS RELATED TO ENERGY AVAILABILITY IN CORN BIOMASS
# 2025-06-05 00:21:36,924 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:38,026 [INFO] TITLE: BIOMASS CHANNEL-GASIFICATION FURNACE
# 2025-06-05 00:21:38,027 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:39,127 [INFO] TITLE: THERMOCHEMICAL CONVERSION OF BIOMASS - GASIFICATION BY FLASH PYROLYSIS STUDY
# 2025-06-05 00:21:39,978 [INFO] No OA PDF for 10.1016/0038-092X(82)90065-2
# 2025-06-05 00:21:41,080 [INFO] TITLE: EFFECT OF P-CRESOL ON LEAF DECOMPOSITION AND INVERTEBRATE COLONIZATION IN EXPERIMENTAL OUTDOOR STREAMS
# 2025-06-05 00:21:41,910 [INFO] No OA PDF for 10.1139/f83-191
# 2025-06-05 00:21:43,011 [INFO] TITLE: FUEL GAS FROM PLANT-SUBSTANCES - ASPECTS AND DEVELOPMENT STAGE OF THE GASIFICATION OF BIOMASSES
# 2025-06-05 00:21:43,011 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:44,113 [INFO] TITLE: UPGRADING OF BIOMASS BY PYROLYSIS AND GASIFICATION PROCESSES
# 2025-06-05 00:21:44,114 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:45,215 [INFO] TITLE: A KINETICS STUDY ON CATALYTIC AND NON-CATALYTIC STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:21:46,038 [INFO] No OA PDF for 10.1016/0378-3820(83)90006-1
# 2025-06-05 00:21:47,139 [INFO] TITLE: CATALYSTS FOR GASIFICATION OF BIOMASS
# 2025-06-05 00:21:47,139 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:48,241 [INFO] TITLE: ALKALI CATALYSIS IN BIOMASS GASIFICATION
# 2025-06-05 00:21:49,063 [INFO] No OA PDF for 10.1016/0165-2370(84)80024-8
# 2025-06-05 00:21:50,165 [INFO] TITLE: MECHANISMS OF CATALYTIC BIOMASS GASIFICATION
# 2025-06-05 00:21:51,004 [INFO] No OA PDF for 10.1016/0165-2370(84)80023-6
# 2025-06-05 00:21:52,106 [INFO] TITLE: DISPOSAL OF EFFLUENTS FROM BIOMASS GASIFICATION SYSTEMS
# 2025-06-05 00:21:52,106 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:53,208 [INFO] TITLE: STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:21:53,208 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:54,309 [INFO] TITLE: LOW-TEMPERATURE GASIFICATION OF HIGH-MOISTURE BIOMASS
# 2025-06-05 00:21:54,309 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:55,411 [INFO] TITLE: GASIFICATION OF BIOMASS
# 2025-06-05 00:21:55,411 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:56,513 [INFO] TITLE: SYSTEM-DESIGN FOR DEHYDRATING FORAGES USING BIOMASS GASIFICATION
# 2025-06-05 00:21:56,513 [INFO] No DOI – skipping download.
# 2025-06-05 00:21:57,615 [INFO] TITLE: THE HETEROTROPHIC AND AUTOTROPHIC GROWTH OF A-EUTROPHUS - RESPONSES TO BIOMASS GASIFICATION IMPURITIES
# 2025-06-05 00:21:59,009 [WARNING] PDF download failed for 10.1002/bit.260261017 – 403 Client Error: Forbidden for url: https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/bit.260261017
# 2025-06-05 00:22:00,110 [INFO] TITLE: ANALYSIS OF CHEMICAL INTERMEDIATES FROM LOW-TEMPERATURE STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:22:00,947 [INFO] No OA PDF for 10.1016/0016-2361(84)90245-X
# 2025-06-05 00:22:02,049 [INFO] TITLE: CATALYTIC STEAM GASIFICATION OF BIOMASS FOR METHANOL AND METHANE PRODUCTION
# 2025-06-05 00:22:02,868 [INFO] No OA PDF for 10.1115/1.3267660
# 2025-06-05 00:22:03,969 [INFO] TITLE: GASIFICATION AND CATALYTIC CONVERSION OF BIOMASS BY FLASH PYROLYSIS
# 2025-06-05 00:22:04,785 [INFO] No OA PDF for 10.1016/0165-2370(85)80104-2
# 2025-06-05 00:22:05,887 [INFO] TITLE: ENERGY FROM BIOMASS AND WASTES - A REVIEW AND 1983 UPDATE
# 2025-06-05 00:22:06,688 [INFO] No OA PDF for 10.1016/0166-3097(85)90001-X
# 2025-06-05 00:22:07,790 [INFO] TITLE: CATALYTIC GASIFICATION OF RICE HULL AND OTHER BIOMASS - THE GENERAL EFFECT OF CATALYST
# 2025-06-05 00:22:08,625 [INFO] No OA PDF for 10.1016/0141-4607(86)90072-7
# 2025-06-05 00:22:09,728 [INFO] TITLE: GASIFICATION OF BIOMASS AND ITS APPLICATION IN THE PULP AND PAPER-INDUSTRY
# 2025-06-05 00:22:09,728 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:10,829 [INFO] TITLE: BIOMASS GASIFICATION
# 2025-06-05 00:22:10,829 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:11,931 [INFO] TITLE: A PROCEDURE TO EVALUATE ENERGY CONTRIBUTION OF BIOMASS
# 2025-06-05 00:22:12,781 [INFO] No OA PDF for 10.1016/0167-5826(86)90030-6
# 2025-06-05 00:22:13,883 [INFO] TITLE: PARAMETERS GOVERNING BIOMASS GASIFICATION
# 2025-06-05 00:22:14,733 [INFO] No OA PDF for 10.1021/ie00062a009
# 2025-06-05 00:22:15,835 [INFO] TITLE: BIOMASS PROPERTIES AND GASIFICATION BEHAVIOR OF 7-YEAR-OLD SIBERIAN ELM
# 2025-06-05 00:22:15,836 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:16,938 [INFO] TITLE: BIOMASS GASIFICATION AS A FUEL SUPPLY FOR LIME KILNS - DESCRIPTION OF RECENT INSTALLATIONS
# 2025-06-05 00:22:16,939 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:18,040 [INFO] TITLE: STEAM GASIFICATION OF BIOMASS WITH NICKEL SECONDARY CATALYSTS
# 2025-06-05 00:22:18,854 [INFO] No OA PDF for 10.1021/ie00067a012
# 2025-06-05 00:22:19,957 [INFO] TITLE: FIXED-BED GASIFICATION OF LIGNOCELLULOSIC BIOMASS - THE CEMAGREF PROCESS
# 2025-06-05 00:22:19,957 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:21,059 [INFO] TITLE: OPTICAL-PROPERTIES OF BIOMASS CHARS IN GASIFICATION
# 2025-06-05 00:22:21,060 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:22,161 [INFO] TITLE: REACTIVITY OF BIOMASS CHARS IN FLUID-BED STEAM GASIFICATION
# 2025-06-05 00:22:22,161 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:23,263 [INFO] TITLE: PYROLYSIS AND STEAM GASIFICATION OF BIOMASS IN FLUIDIZED-BEDS - INFLUENCE OF THE TYPE AND LOCATION OF THE BIOMASS FEEDING POINT ON THE PRODUCT DISTRIBUTION
# 2025-06-05 00:22:23,263 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:24,365 [INFO] TITLE: A PILOT-PLANT FOR THE STUDY OF THE PRODUCTION OF HYDROGEN-RICH SYNGAS BY GASIFICATION OF BIOMASS
# 2025-06-05 00:22:24,366 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:25,467 [INFO] TITLE: LOW-TEMPERATURE GASIFICATION OF HIGH-MOISTURE BIOMASS
# 2025-06-05 00:22:25,468 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:26,569 [INFO] TITLE: FLUIDIZED-BED STEAM GASIFICATION OF BIOMASS WITH DOLOMITE AND WITH A COMMERCIAL FCC CATALYST
# 2025-06-05 00:22:26,570 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:27,671 [INFO] TITLE: PROCESS ANALYSIS OF A DUAL FLUIDIZED-BED BIOMASS GASIFICATION SYSTEM
# 2025-06-05 00:22:28,523 [INFO] No OA PDF for 10.1021/ie00074a016
# 2025-06-05 00:22:29,625 [INFO] TITLE: MODELING AND APPLICATION OF BIOMASS GASIFICATION BASED POWER-GENERATION SYSTEMS
# 2025-06-05 00:22:29,625 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:30,726 [INFO] TITLE: THE AVSA BIOMASS GASIFICATION PROCESS
# 2025-06-05 00:22:30,727 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:31,828 [INFO] TITLE: SYNTHESIS OF HYDROCARBONS FROM PLANT BIOMASS AIR GASIFICATION PRODUCTS
# 2025-06-05 00:22:31,829 [INFO] No DOI – skipping download.
# 2025-06-05 00:22:32,931 [INFO] TITLE: DEVELOPMENT AND FIELD TESTING OF SMALL BIOMASS GASIFIER-ENGINE SYSTEMS IN INDIA - A JOINT PROJECT BY AN AMERICAN AND INDIAN TEAM
# 2025-06-05 00:22:33,758 [INFO] No OA PDF for 10.1016/0144-4565(89)90009-7
# 2025-06-05 00:22:34,859 [INFO] TITLE: BIOMASS GASIFICATION - FIELD MONITORING RESULTS
# 2025-06-05 00:22:35,702 [INFO] No OA PDF for 10.1016/0144-4565(89)90003-6
# 2025-06-05 00:22:36,804 [INFO] TITLE: BIOMASS GASIFICATION RESEARCH AND FIELD DEVELOPMENTS BY THE PRINCE-OF-SONGKLA-UNIVERSITY, THAILAND
# 2025-06-05 00:22:37,639 [INFO] No OA PDF for 10.1016/0144-4565(89)90036-X
# 2025-06-05 00:22:38,741 [INFO] TITLE: OVERVIEW OF BIOMASS GASIFICATION IN THE USA
# 2025-06-05 00:22:39,570 [INFO] No OA PDF for 10.1016/0144-4565(89)90030-9
# 2025-06-05 00:22:40,672 [INFO] TITLE: BIOMASS GASIFICATION - FIELD MONITORING RESULTS
# 2025-06-05 00:22:41,486 [INFO] No OA PDF for 10.1016/0144-4565(89)90002-4
# 2025-06-05 00:22:42,588 [INFO] TITLE: THE COMMERCIAL RESPONSIBILITIES OF BIOMASS GASIFICATION
# 2025-06-05 00:22:43,398 [INFO] No OA PDF for 10.1016/0144-4565(89)90010-3
# 2025-06-05 00:22:44,500 [INFO] TITLE: BIOMASS GASIFICATION .1. SPECIAL ISSUE
# 2025-06-05 00:22:45,335 [INFO] No OA PDF for 10.1016/0144-4565(89)90029-2
# 2025-06-05 00:22:46,436 [INFO] TITLE: UPDRAFT GASIFICATION OF PEAT AND BIOMASS
# 2025-06-05 00:22:47,238 [INFO] No OA PDF for 10.1016/0144-4565(89)90004-8
# 2025-06-05 00:22:48,340 [INFO] TITLE: BIOMASS GASIFICATION - DEVELOPMENT COOPERATION IN BELGIUM
# 2025-06-05 00:22:49,149 [INFO] No OA PDF for 10.1016/0144-4565(89)90039-5
# 2025-06-05 00:22:50,250 [INFO] TITLE: ITALIAN ACTIVITIES IN BIOMASS GASIFICATION
# 2025-06-05 00:22:51,061 [INFO] No OA PDF for 10.1016/0144-4565(89)90037-1
# 2025-06-05 00:22:52,163 [INFO] TITLE: BIOMASS GASIFICATION IN INDONESIA
# 2025-06-05 00:22:53,003 [INFO] No OA PDF for 10.1016/0144-4565(89)90035-8
# 2025-06-05 00:22:54,104 [INFO] TITLE: BIOMASS THERMAL GASIFICATION RESEARCH - RECENT RESULTS FROM THE UNITED-STATES DOES RESEARCH-PROGRAM
# 2025-06-05 00:22:54,939 [INFO] No OA PDF for 10.1016/0144-4565(89)90012-7
# 2025-06-05 00:22:56,041 [INFO] TITLE: THE FLUIDIZED-BED GASIFICATION OF BIOMASS - EXPERIMENTAL STUDIES ON A BENCH SCALE REACTOR
# 2025-06-05 00:22:56,851 [INFO] No OA PDF for 10.1016/0144-4565(89)90011-5
# 2025-06-05 00:22:57,954 [INFO] TITLE: ASSESSMENT OF CURRENT STATUS AND THE POTENTIAL FOR COMMERCIAL EXPLOITATION OF BIOMASS GASIFICATION IN INDIA
# 2025-06-05 00:22:58,773 [INFO] No OA PDF for 10.1016/0144-4565(89)90034-6
# 2025-06-05 00:22:59,875 [INFO] TITLE: STATUS OF PEAT AND BIOMASS GASIFICATION IN FINLAND
# 2025-06-05 00:23:00,711 [INFO] No OA PDF for 10.1016/0144-4565(89)90038-3
# 2025-06-05 00:23:01,813 [INFO] TITLE: BIOMASS GASIFICATION IN INDIA - DNES ACTIVITIES
# 2025-06-05 00:23:02,610 [INFO] No OA PDF for 10.1016/0144-4565(89)90033-4
# 2025-06-05 00:23:03,711 [INFO] TITLE: A MODEL FOR TAR-REMOVAL EFFICIENCY FROM BIOMASS-PRODUCED GAS IMPINGING ON A WATER-SURFACE
# 2025-06-05 00:23:04,550 [INFO] No OA PDF for 10.1016/0360-5442(89)90054-6
# 2025-06-05 00:23:05,652 [INFO] TITLE: COMMERCIAL BIOMASS GASIFICATION IN DEVELOPING-COUNTRIES
# 2025-06-05 00:23:05,652 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:06,754 [INFO] TITLE: ECONOMIC-ASSESSMENT OF ADVANCED BIOMASS GASIFICATION SYSTEMS
# 2025-06-05 00:23:06,755 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:07,855 [INFO] TITLE: RETROFIT APPLICATIONS OF WOODY BIOMASS GASIFICATION COMMERCIAL CASE-HISTORIES OF OPERATING PLANTS
# 2025-06-05 00:23:07,855 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:08,957 [INFO] TITLE: HIGH-PRESSURE SYNTHESIS OF LIQUID HYDROCARBONS FROM THE PRODUCT OF BIOMASS GASIFICATION
# 2025-06-05 00:23:08,957 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:10,058 [INFO] TITLE: GASIFICATION OF AGRICULTURAL RESIDUES (BIOMASS) - INFLUENCE OF INORGANIC CONSTITUENTS
# 2025-06-05 00:23:10,877 [INFO] No OA PDF for 10.1021/jf00091a070
# 2025-06-05 00:23:11,979 [INFO] TITLE: A PROCESS FOR CATALYTIC GASIFICATION OF BIOMASS
# 2025-06-05 00:23:11,979 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:13,080 [INFO] TITLE: GASIFICATION AND PYROLYSIS OF BIOMASS IN EUROPE
# 2025-06-05 00:23:13,082 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:14,183 [INFO] TITLE: STEAM GASIFICATION OF BIOMASS IN FLUIDIZED-BED WITH A SECONDARY CATALYTIC BED .4. USE OF METHANE STEAM REFORMING CATALYSTS
# 2025-06-05 00:23:14,184 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:15,286 [INFO] TITLE: GASIFICATION OF BIOMASS WITH TAR CRACKING CATALYSTS IN A CIRCULATING MULTISOLID FLUIDIZED-BED PILOT-PLANT
# 2025-06-05 00:23:15,287 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:16,388 [INFO] TITLE: GASIFICATION OF BIOMASS IN FIXED-BED
# 2025-06-05 00:23:16,389 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:17,490 [INFO] TITLE: STEAM GASIFICATION OF BIOMASS IN FLUIDIZED-BED WITH A SECONDARY CATALYTIC BED .3. USE OF METHANATION CATALYSTS
# 2025-06-05 00:23:17,490 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:18,591 [INFO] TITLE: FLUIDIZED-BED COMBUSTION AND GASIFICATION OF BIOMASS
# 2025-06-05 00:23:18,592 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:19,693 [INFO] TITLE: GASIFICATION OF BIOMASS - NEED FOR FURTHER R-AND-D
# 2025-06-05 00:23:19,693 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:20,794 [INFO] TITLE: PROSPECTS FOR COMMERCIALIZATION OF BIOMASS GASIFICATION SYSTEMS IN DEVELOPING-COUNTRIES - A CASE-STUDY IN INDONESIA
# 2025-06-05 00:23:20,794 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:21,895 [INFO] TITLE: THERMODYNAMICS OF PRESSURIZED AIR-STEAM GASIFICATION OF BIOMASS
# 2025-06-05 00:23:21,896 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:22,998 [INFO] TITLE: GASIFICATION OF GLUCOSE AND WET BIOMASS IN SUPERCRITICAL WATER
# 2025-06-05 00:23:22,998 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:24,100 [INFO] TITLE: GASIFICATION OF BIOMASS CHARS IN CARBON-DIOXIDE - DEPENDENCE OF GASIFICATION RATE ON THE INDIGENOUS METAL CONTENT
# 2025-06-05 00:23:24,953 [INFO] No OA PDF for 10.1016/0016-2361(90)90041-N
# 2025-06-05 00:23:26,054 [INFO] TITLE: THERMAL-DEGRADATION OF VOLATILE PYROLYSIS PRODUCTS IN THE CRUDE GASEOUS PRODUCTS OF COAL AND BIOMASS GASIFICATION - KINETIC-STUDIES ON MODEL SUBSTANCES
# 2025-06-05 00:23:26,868 [INFO] No OA PDF for 10.1002/cite.330620716
# 2025-06-05 00:23:27,970 [INFO] TITLE: SYNTHESIS GAS FROM PEAT - A FINNISH PEAT AMMONIA VENTURE
# 2025-06-05 00:23:28,787 [INFO] No OA PDF for 10.1080/00908319108908972
# 2025-06-05 00:23:29,888 [INFO] TITLE: EQUILIBRIUM MODELING OF A DOWNDRAFT GASIFIER .1. OVERALL GASIFIER
# 2025-06-05 00:23:30,727 [INFO] No OA PDF for 10.1080/00986449108910961
# 2025-06-05 00:23:31,828 [INFO] TITLE: NEW ECOLOGICALLY ACCEPTABLE METHODS FOR FUEL AND POWER PRODUCTION FROM BIOMASS AND PEAT
# 2025-06-05 00:23:32,595 [INFO] No OA PDF for 10.1080/00908319108908971
# 2025-06-05 00:23:33,698 [INFO] TITLE: CHEMICAL-EQUILIBRIUM COMPUTATIONS FOR GASIFICATION OF BIOMASS TO PRODUCE METHANOL
# 2025-06-05 00:23:34,507 [INFO] No OA PDF for 10.1080/00908319108908994
# 2025-06-05 00:23:35,609 [INFO] TITLE: METHANE FERMENTATION OF WOODY BIOMASS
# 2025-06-05 00:23:36,439 [INFO] No OA PDF for 10.1016/0960-8524(91)90202-U
# 2025-06-05 00:23:37,540 [INFO] TITLE: THE USE OF FORESTRY BIOMASS FOR ENERGY - COMBUSTION VERSUS GASIFICATION IN FLUIDIZED-BEDS
# 2025-06-05 00:23:37,541 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:38,641 [INFO] TITLE: DEMONSTRATION PLANT FOR PRESSURIZED GASIFICATION OF BIOMASS FEEDSTOCKS
# 2025-06-05 00:23:38,642 [INFO] No DOI – skipping download.
# 2025-06-05 00:23:39,744 [INFO] TITLE: REMOVAL OF PARTICULATES AND ALKALI-METALS FROM PRESSURIZED FLUID-BED GASIFICATION OF PEAT AND BIOMASS - GAS CLEANUP FOR GAS-TURBINE APPLICATIONS
# 2025-06-05 00:23:39,745 [INFO] No DOI – skipping download.
